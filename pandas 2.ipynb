# %%
import pandas as pd

df = pd.read_csv('avocado.csv')
df['Date'] = pd.to_datetime(df["Date"]) 
albany_df = df[df["region"]=='Albany']
albany_df.set_index("Date", inplace=True)
albany_df["AveragePrice"].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
albany_df["AveragePrice"].rolling(25).mean().plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
albany_df.index
# Out:
# DatetimeIndex(['2015-12-27', '2015-12-20', '2015-12-13', '2015-12-06',
#                '2015-11-29', '2015-11-22', '2015-11-15', '2015-11-08',
#                '2015-11-01', '2015-10-25',
#                ...
#                '2018-03-11', '2018-03-04', '2018-02-25', '2018-02-18',
#                '2018-02-11', '2018-02-04', '2018-01-28', '2018-01-21',
#                '2018-01-14', '2018-01-07'],
#               dtype='datetime64[ns]', name='Date', length=338, freq=None)

# %%
albany_df.sort_index(inplace=True)
albany_df["AveragePrice"].rolling(25).mean().plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
albany_df['price25ma'] = albany_df["AveragePrice"].rolling(25).mean()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
albany_df.head(3)
# Out:
#             Unnamed: 0  AveragePrice  Total Volume     4046      4225    4770  \
# Date
# 2015-01-04          51          1.22      40873.28  2819.50  28287.42   49.90
# 2015-01-04          51          1.79       1373.95    57.42    153.88    0.00
# 2015-01-11          50          1.24      41195.08  1002.85  31640.34  127.12
#
#             Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# Date
# 2015-01-04     9716.46     9186.93      529.53          0.0  conventional
# 2015-01-04     1162.65     1162.65        0.00          0.0       organic
# 2015-01-11     8424.77     8036.04      388.73          0.0  conventional
#
#             year  region  price25ma
# Date
# 2015-01-04  2015  Albany        NaN
# 2015-01-04  2015  Albany        NaN
# 2015-01-11  2015  Albany        NaN

# %%
albany_df.tail()
# Out:
#             Unnamed: 0  AveragePrice  Total Volume      4046       4225  \
# Date
# 2018-03-11           2          1.68       2570.52    131.67     229.56
# 2018-03-18           1          1.66       3154.45    275.89     297.96
# 2018-03-18           1          1.35     105304.65  13234.86   61037.58
# 2018-03-25           0          1.57     149396.50  16361.69  109045.03
# 2018-03-25           0          1.71       2321.82     42.95     272.41
#
#              4770  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# Date
# 2018-03-11   0.00     2209.29     2209.29        0.00          0.0
# 2018-03-18   0.00     2580.60     2577.27        3.33          0.0
# 2018-03-18  55.00    30977.21    26755.90     3721.31        500.0
# 2018-03-25  65.45    23924.33    19273.80     4270.53        380.0
# 2018-03-25   0.00     2006.46     1996.46       10.00          0.0
#
#                     type  year  region  price25ma
# Date
# 2018-03-11       organic  2018  Albany     1.4224
# 2018-03-18       organic  2018  Albany     1.4316
# 2018-03-18  conventional  2018  Albany     1.4276
# 2018-03-25  conventional  2018  Albany     1.4272
# 2018-03-25       organic  2018  Albany     1.4368

# %%
albany_df.dropna().head(3)
# Out:
#             Unnamed: 0  AveragePrice  Total Volume     4046      4225   4770  \
# Date
# 2015-03-29          39          1.93       1082.44    24.75    173.26   0.00
# 2015-03-29          39          1.02      67799.08  1402.28  58623.22  89.50
# 2015-04-05          38          1.16      47362.13   961.77  35577.66  93.76
#
#             Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# Date
# 2015-03-29      884.43      884.43        0.00         0.00       organic
# 2015-03-29     7684.08     7208.49      475.59         0.00  conventional
# 2015-04-05    10728.94     9869.16      755.61       104.17  conventional
#
#             year  region  price25ma
# Date
# 2015-03-29  2015  Albany     1.4660
# 2015-03-29  2015  Albany     1.4580
# 2015-04-05  2015  Albany     1.4328

# %%
albany_df = df.copy([df['region'] == 'Alabny'])
albany_df.set_index("Date", inplace=True)
albany_df.sort_index(inplace=True)
albany_df['price25ma'] = albany_df['AveragePrice'].rolling(25).mean()

# %%
list(set(df["region"].values.tolist()))
# Out:
# ['Detroit',
#  'TotalUS',
#  'Houston',
#  'RichmondNorfolk',
#  'Boston',
#  'BuffaloRochester',
#  'California',
#  'Northeast',
#  'HarrisburgScranton',
#  'SanDiego',
#  'Midsouth',
#  'Roanoke',
#  'BaltimoreWashington',
#  'LosAngeles',
#  'West',
#  'Columbus',
#  'Chicago',
#  'RaleighGreensboro',
#  'DallasFtWorth',
#  'Atlanta',
#  'CincinnatiDayton',
#  'NewYork',
#  'NewOrleansMobile',
#  'Pittsburgh',
#  'Jacksonville',
#  'Indianapolis',
#  'Albany',
#  'HartfordSpringfield',
#  'Southeast',
#  'Sacramento',
#  'Nashville',
#  'PhoenixTucson',
#  'Seattle',
#  'Spokane',
#  'Philadelphia',
#  'Boise',
#  'SouthCarolina',
#  'Louisville',
#  'SanFrancisco',
#  'WestTexNewMexico',
#  'Orlando',
#  'SouthCentral',
#  'Tampa',
#  'Plains',
#  'GreatLakes',
#  'MiamiFtLauderdale',
#  'StLouis',
#  'Syracuse',
#  'Portland',
#  'LasVegas',
#  'Charlotte',
#  'NorthernNewEngland',
#  'Denver',
#  'GrandRapids']

# %%
df['region'].unique()
# Out:
# array(['Albany', 'Atlanta', 'BaltimoreWashington', 'Boise', 'Boston',
#        'BuffaloRochester', 'California', 'Charlotte', 'Chicago',
#        'CincinnatiDayton', 'Columbus', 'DallasFtWorth', 'Denver',
#        'Detroit', 'GrandRapids', 'GreatLakes', 'HarrisburgScranton',
#        'HartfordSpringfield', 'Houston', 'Indianapolis', 'Jacksonville',
#        'LasVegas', 'LosAngeles', 'Louisville', 'MiamiFtLauderdale',
#        'Midsouth', 'Nashville', 'NewOrleansMobile', 'NewYork',
#        'Northeast', 'NorthernNewEngland', 'Orlando', 'Philadelphia',
#        'PhoenixTucson', 'Pittsburgh', 'Plains', 'Portland',
#        'RaleighGreensboro', 'RichmondNorfolk', 'Roanoke', 'Sacramento',
#        'SanDiego', 'SanFrancisco', 'Seattle', 'SouthCarolina',
#        'SouthCentral', 'Southeast', 'Spokane', 'StLouis', 'Syracuse',
#        'Tampa', 'TotalUS', 'West', 'WestTexNewMexico'], dtype=object)

# %%
#restructuring
graph_df = pd.DataFrame()
for region in df["region"].unique()[:16]:
    print(region)
    region_df = df.copy()[df["region"]==region]
    region_df.set_index("Date", inplace=True)
    region_df.sort_index(inplace=True)
    region_df[f'{region}_price25ma'] = region_df['AveragePrice'].rolling(25).mean()
    
    if graph_df.empty:
        graph_df = region_df[[f'{region}_price25ma',]]
        
    else:
        graph_df = graph_df.join(region_df[f'{region}_price25ma'])
# Out:
# Albany
# Atlanta
# BaltimoreWashington
# Boise
# Boston
# BuffaloRochester
# California
# Charlotte
# Chicago
# CincinnatiDayton
# Columbus
# DallasFtWorth
# Denver
# Detroit
# GrandRapids
# GreatLakes

# %%
graph_df.tail()
# Out:
#             Albany_price25ma  Atlanta_price25ma  \
# Date
# 2018-03-25            1.4368             1.2884
# 2018-03-25            1.4368             1.2884
# 2018-03-25            1.4368             1.2884
# 2018-03-25            1.4368             1.2884
# 2018-03-25            1.4368             1.2884
#
#             BaltimoreWashington_price25ma  Boise_price25ma  Boston_price25ma  \
# Date
# 2018-03-25                         1.3844           1.5016             1.588
# 2018-03-25                         1.3844           1.5016             1.588
# 2018-03-25                         1.3844           1.5016             1.588
# 2018-03-25                         1.3844           1.5016             1.588
# 2018-03-25                         1.3844           1.5016             1.588
#
#             BuffaloRochester_price25ma  California_price25ma  \
# Date
# 2018-03-25                      1.2232                1.4232
# 2018-03-25                      1.2232                1.4232
# 2018-03-25                      1.2232                1.4232
# 2018-03-25                      1.2232                1.4232
# 2018-03-25                      1.2232                1.4232
#
#             Charlotte_price25ma  Chicago_price25ma  \
# Date
# 2018-03-25               1.4916             1.5708
# 2018-03-25               1.4916             1.5708
# 2018-03-25               1.4916             1.5708
# 2018-03-25               1.4916             1.5708
# 2018-03-25               1.4916             1.5708
#
#             CincinnatiDayton_price25ma  Columbus_price25ma  \
# Date
# 2018-03-25                      1.2792              1.1704
# 2018-03-25                      1.2792              1.1704
# 2018-03-25                      1.2792              1.1704
# 2018-03-25                      1.2792              1.1704
# 2018-03-25                      1.2792              1.1704
#
#             DallasFtWorth_price25ma  Denver_price25ma  Detroit_price25ma  \
# Date
# 2018-03-25                    1.118            1.2888             1.1492
# 2018-03-25                    1.118            1.2888             1.1728
# 2018-03-25                    1.118            1.2888             1.1728
# 2018-03-25                    1.118            1.2888             1.1728
# 2018-03-25                    1.118            1.2888             1.1728
#
#             GrandRapids_price25ma  GreatLakes_price25ma
# Date
# 2018-03-25                 1.3264                1.2788
# 2018-03-25                 1.3164                1.2568
# 2018-03-25                 1.3164                1.2788
# 2018-03-25                 1.3264                1.2568
# 2018-03-25                 1.3264                1.2788

# %%
import pandas as pd

df = pd.read_csv('avocado.csv')

df = df.copy()[df['type'] == 'organic']
df['Date'] = pd.to_datetime(df["Date"])

df.sort_values(by="Date", ascending="True, inplace=True")

df.head()
# Out:
#       Unnamed: 0       Date  AveragePrice  Total Volume   4046    4225  4770  \
# 9126           0 2015-12-27          1.83        989.55   8.16   88.59   0.0
# 9127           1 2015-12-20          1.89       1163.03  30.24  172.14   0.0
# 9128           2 2015-12-13          1.85        995.96  10.44  178.70   0.0
# 9129           3 2015-12-06          1.84       1158.42  90.29  104.18   0.0
# 9130           4 2015-11-29          1.94        831.69   0.00   94.73   0.0
#
#       Total Bags  Small Bags  Large Bags  XLarge Bags     type  year  region
# 9126      892.80      892.80        0.00          0.0  organic  2015  Albany
# 9127      960.65      960.65        0.00          0.0  organic  2015  Albany
# 9128      806.82      806.82        0.00          0.0  organic  2015  Albany
# 9129      963.95      948.52       15.43          0.0  organic  2015  Albany
# 9130      736.96      736.96        0.00          0.0  organic  2015  Albany

# %%
graph_df = pd.DataFrame()
for region in df["region"].unique():
    print(region)
    region_df = df.copy()[df["region"]==region]
    region_df.set_index("Date", inplace=True)
    region_df.sort_index(inplace=True)
    region_df[f'{region}_price25ma'] = region_df['AveragePrice'].rolling(25).mean()
    
    if graph_df.empty:
        graph_df = region_df[[f'{region}_price25ma',]]
        
    else:
        graph_df = graph_df.join(region_df[f'{region}_price25ma'])
        
graph_df.tail()
# Out:
# Albany
# Atlanta
# BaltimoreWashington
# Boise
# Boston
# BuffaloRochester
# California
# Charlotte
# Chicago
# CincinnatiDayton
# Columbus
# DallasFtWorth
# Denver
# Detroit
# GrandRapids
# GreatLakes
# HarrisburgScranton
# HartfordSpringfield
# Houston
# Indianapolis
# Jacksonville
# LasVegas
# LosAngeles
# Louisville
# MiamiFtLauderdale
# Midsouth
# Nashville
# NewOrleansMobile
# NewYork
# Northeast
# NorthernNewEngland
# Orlando
# Philadelphia
# PhoenixTucson
# Pittsburgh
# Plains
# Portland
# RaleighGreensboro
# RichmondNorfolk
# Roanoke
# Sacramento
# SanDiego
# SanFrancisco
# Seattle
# SouthCarolina
# SouthCentral
# Southeast
# Spokane
# StLouis
# Syracuse
# Tampa
# TotalUS
# West
# WestTexNewMexico
#             Albany_price25ma  Atlanta_price25ma  \
# Date
# 2018-02-25            1.5112             1.8660
# 2018-03-04            1.4992             1.8288
# 2018-03-11            1.5044             1.7844
# 2018-03-18            1.5140             1.7412
# 2018-03-25            1.5188             1.6936
#
#             BaltimoreWashington_price25ma  Boise_price25ma  Boston_price25ma  \
# Date
# 2018-02-25                         1.5836           2.0512            1.7636
# 2018-03-04                         1.5772           2.0176            1.7708
# 2018-03-11                         1.5732           1.9836            1.7824
# 2018-03-18                         1.5684           1.9520            1.7932
# 2018-03-25                         1.5568           1.9128            1.7984
#
#             BuffaloRochester_price25ma  California_price25ma  \
# Date
# 2018-02-25                      1.2912                1.9128
# 2018-03-04                      1.2744                1.8876
# 2018-03-11                      1.2652                1.8636
# 2018-03-18                      1.2560                1.8516
# 2018-03-25                      1.2416                1.8364
#
#             Charlotte_price25ma  Chicago_price25ma  \
# Date
# 2018-02-25               2.0548             1.8160
# 2018-03-04               2.0180             1.8024
# 2018-03-11               1.9764             1.7836
# 2018-03-18               1.9444             1.7732
# 2018-03-25               1.9024             1.7672
#
#             CincinnatiDayton_price25ma  ...  SouthCarolina_price25ma  \
# Date                                    ...
# 2018-02-25                      1.7752  ...                   1.6184
# 2018-03-04                      1.7564  ...                   1.5952
# 2018-03-11                      1.7216  ...                   1.5612
# 2018-03-18                      1.6860  ...                   1.5312
# 2018-03-25                      1.6720  ...                   1.5004
#
#             SouthCentral_price25ma  Southeast_price25ma  Spokane_price25ma  \
# Date
# 2018-02-25                  1.5728               1.7116             2.1544
# 2018-03-04                  1.5592               1.6868             2.1040
# 2018-03-11                  1.5400               1.6484             2.0552
# 2018-03-18                  1.5204               1.6156             2.0012
# 2018-03-25                  1.5072               1.5820             1.9496
#
#             StLouis_price25ma  Syracuse_price25ma  Tampa_price25ma  \
# Date
# 2018-02-25             1.9240              1.3156           1.7204
# 2018-03-04             1.8868              1.3004           1.7104
# 2018-03-11             1.8468              1.2932           1.6916
# 2018-03-18             1.8192              1.2848           1.6776
# 2018-03-25             1.7976              1.2700           1.6484
#
#             TotalUS_price25ma  West_price25ma  WestTexNewMexico_price25ma
# Date
# 2018-02-25             1.7144          1.8620                      1.8708
# 2018-03-04             1.6940          1.8220                      1.8372
# 2018-03-11             1.6748          1.7912                      1.8052
# 2018-03-18             1.6588          1.7644                      1.7772
# 2018-03-25             1.6428          1.7304                      1.7472
#
# [5 rows x 54 columns]

# %%
graph_df.dropna().plot(figsize = (8,5), legend= False)
# Out:
# <AxesSubplot:xlabel='Date'>
